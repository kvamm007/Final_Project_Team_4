# %%
# Import dependencies
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
import psycopg2

#from config import db_password

# %%
# Set file directory path
file_dir = 'C:/Users/Bauer/Desktop/Analysis Projects/Final_Project_Team_4/Resources'
# Shark attack data file
shark_file = f'{file_dir}/GSAF5.csv'

# %%
# Read csv file into a dataframe
shark_attack_df = pd.read_csv(shark_file, low_memory=False)
shark_attack_df.head()
# Out:
#     Case Number         Date    Year        Type                     Country  \
# 0    2021.09.10  10-Sep-2021  2021.0         NaN                       EGYPT
# 1    2021.09.09  09-Sep-2021  2021.0  Unprovoked                         USA
# 2    2021.09.05  05-Sep-2021  2021.0  Unprovoked                   AUSTRALIA
# 3  2021.09.03.b  03-Sep-2021  2021.0  Unprovoked  British Overseas Territory
# 4    2021.08.28  28-Aug-2021  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#                Name Sex   ... Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# 0           Mohamed    M  ...          NaN          NaN          NaN
# 1     Doyle Neilsen    M  ...          NaN          NaN          NaN
# 2  Timothy Thompson    M  ...          NaN          NaN          NaN
# 3              male    M  ...          NaN          NaN          NaN
# 4              male    M  ...          NaN          NaN          NaN
#
#   Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 254 Unnamed: 255
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 256 columns]

# %%
# Remove all of the extra "unnamed" columns at the end of the dataset
for column in shark_attack_df.columns:
    if 'Unnamed:' in column:
        shark_attack_df.drop(columns=column, inplace=True)

shark_attack_df.head()
# Out:
#     Case Number         Date    Year        Type                     Country  \
# 0    2021.09.10  10-Sep-2021  2021.0         NaN                       EGYPT
# 1    2021.09.09  09-Sep-2021  2021.0  Unprovoked                         USA
# 2    2021.09.05  05-Sep-2021  2021.0  Unprovoked                   AUSTRALIA
# 3  2021.09.03.b  03-Sep-2021  2021.0  Unprovoked  British Overseas Territory
# 4    2021.08.28  28-Aug-2021  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#                Name Sex   ... Fatal (Y/N)   Time               Species   \
# 0           Mohamed    M  ...         NaN    NaN  No shark invovlement
# 1     Doyle Neilsen    M  ...           N  13h20                    NaN
# 2  Timothy Thompson    M  ...           Y  10h30            White xhark
# 3              male    M  ...           N    NaN                    NaN
# 4              male    M  ...           N  11h45                    NaN
#
#                              Investigator or Source  \
# 0                           Dr. M. Fouda & M. Salrm
# 1             Daytona Beach News-Journal, 9/14/2021
# 2                                    B. Myatt, GSAF
# 3                                         Anonymous
# 4  T. Craig, GSAF  & K. McMurray, TrackingShark.com
#
#                             pdf  \
# 0        2021.09.10-Mohamed.pdf
# 1        2021.09.09-Neilsen.pdf
# 2       2021.09.05-Thompson.pdf
# 3  2021.09.03.b-TurksCaicos.pdf
# 4     2021.08.28.-Galveston.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.10
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.09
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.05
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2021.09.03.b
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.08.28
#
#   Case Number.2 original order
# 0    2021.09.10         6700.0
# 1    2021.09.09         6699.0
# 2    2021.09.05         6698.0
# 3  2021.09.03.b         6697.0
# 4    2021.08.28         6696.0
#
# [5 rows x 22 columns]

# %%
# Drop duplicate Case Number and href columns
shark_attack_df.drop(columns=['Case Number.1','Case Number.2','href'], inplace=True)

# Drop unnecessary columns
shark_attack_df.drop(columns=['Name', 'Investigator or Source', 'pdf'], inplace=True)

shark_attack_df.head()
# Out:
#     Case Number         Date    Year        Type                     Country  \
# 0    2021.09.10  10-Sep-2021  2021.0         NaN                       EGYPT
# 1    2021.09.09  09-Sep-2021  2021.0  Unprovoked                         USA
# 2    2021.09.05  05-Sep-2021  2021.0  Unprovoked                   AUSTRALIA
# 3  2021.09.03.b  03-Sep-2021  2021.0  Unprovoked  British Overseas Territory
# 4    2021.08.28  28-Aug-2021  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#                Name Sex   Age  \
# 0           Mohamed    M  NaN
# 1     Doyle Neilsen    M   !6
# 2  Timothy Thompson    M   31
# 3              male    M  NaN
# 4              male    M   !!
#
#                                               Injury Fatal (Y/N)   Time  \
# 0           Laceration to arm caused by metal object         NaN    NaN
# 1                          Minor injury to right arm           N  13h20
# 2                                              FATAL           Y  10h30
# 3                                       Wrist bitten           N    NaN
# 4  Lacerations both sides of lower leg immediatel...           N  11h45
#
#                 Species                             Investigator or Source  \
# 0  No shark invovlement                            Dr. M. Fouda & M. Salrm
# 1                    NaN             Daytona Beach News-Journal, 9/14/2021
# 2            White xhark                                    B. Myatt, GSAF
# 3                    NaN                                         Anonymous
# 4                    NaN  T. Craig, GSAF  & K. McMurray, TrackingShark.com
#
#                             pdf  \
# 0        2021.09.10-Mohamed.pdf
# 1        2021.09.09-Neilsen.pdf
# 2       2021.09.05-Thompson.pdf
# 3  2021.09.03.b-TurksCaicos.pdf
# 4     2021.08.28.-Galveston.pdf
#
#                                         href formula  original order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6700.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6699.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6698.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6697.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6696.0

# %%
shark_attack_df.dtypes

# %%
shark_attack_df['Type'].value_counts()
# Out:
# Unprovoked             4908
# Provoked                613
# Invalid                 552
# Watercraft              350
# Sea Disaster            240
# Questionable             12
# Boat                      7
# Under investigation       1
# Unverified                1
# Unconfirmed               1
# Name: Type, dtype: int64

# %%
shark_attack_df['Fatal (Y/N)'].value_counts()
# Out:
# N          4634
# Y          1427
# UNKNOWN      71
#  N            7
# F             2
# N             1
# M             1
# y             1
# Y x 2         1
# 2017          1
# Nq            1
# Name: Fatal (Y/N), dtype: int64

# %%
shark_attack_df['Activity'].value_counts().to_list
# Out:
# <bound method IndexOpsMixin.tolist of Surfing                                                           1072
# Swimming                                                           922
# Fishing                                                            468
# Spearfishing                                                       366
# Wading                                                             166
#                                                                   ...
# Body found on deserted luxury yacht, 38’ Christine                   1
# Sponge divers                                                        1
# 13 men in the water after sailboat capsized & sank                   1
# Arsinoe, a French tanker                                             1
# In rubber dinghy with Captain Eddie Rickenbacker for 21 days.        1
# Name: Activity, Length: 1563, dtype: int64>

# %%
# Set up engine to transfer our shark attack df to PostgreSQL
#db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/shark_attack_data"
#engine = create_engine(db_string)
    
# Upload shark_attack_df to a SQL database
#shark_attack_df.to_sql(name='shark_attacks', con=engine, if_exists='replace')
