# %%
# Data cleaning strategy
# 1. Remove all unnecessary columns
#      Blank columns at the end of the dataset
#      Case Number, Name, Investigator, PDF, original order, Species, and extra href as we do not need those for our analysis
# 2. Clean up Year column
#      Change to integer type
#      Remove all rows that are from before 1950
# 3. Clean up the 'Type' column
#      Remove rows of type "Invalid" as those look to be incidents determined to be not shark-related
#      Remove rows of type "Questionable", "Unconfirmed", "Unverified", or "Under Investigation" as they are not 
#             confirmed as shark incidents
#      Combine Boat and Watercraft records as they are the same type
# 4. Clean up Date column
#      Use Case Number field for this as it is built on the date and actually cleaner
#      Make the date column a valid and consistent date/time format
# 5. Clean up the 'Fatal (Y/N)' column
#      Rename to just 'Fatal'
#      Replace values that are not "Y", "N", or "UNKNOWN" with appropriate values
# 6. Clean up Gender column
#      Make sure all rows are either "M", "F", or "Unknown"
# 7. Clean up Age column
#      Convert to number type (no age given will be listed as 0)
# 8. Clean up Time column
#      Convert to a valid time format
# 9. Clean up Activity column
#      Standardize activities??  Can keywords be pulled out??  Boating, surfing, swimming, etc...

# %%
# Import dependencies
import pandas as pd
import numpy as np
import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

# %%
# Set file directory path
file_dir = 'C:/Users/Bauer/Desktop/Analysis Projects/Final_Project_Team_4/Resources'
# Shark attack data file
shark_file = f'{file_dir}/GSAF5.csv'
# ISO code file
ISO_code_file = f'{file_dir}/ISO_Codes.csv'

# %%
# Read the ISO code file csv file into a dataframe
ISO_df = pd.read_csv(ISO_code_file, low_memory=False)
ISO_df.head()
# Out:
#                                  Official state name ISO Code
# 0                                              �LAND       AX
# 1  ALL LAND AND ICE SHELVES SOUTH OF THE�60TH PAR...       AQ
# 2                                           ANGUILLA       AI
# 3                                ANTIGUA AND BARBUDA       AG
# 4                                              ARUBA       AW

# %%
# Rename column names
ISO_df.rename(columns = {'ISO Code':'ISO_code'}, inplace = True)

# %%
# Read shark attack csv file into a dataframe
shark_attack_df = pd.read_csv(shark_file, low_memory=False)
shark_attack_df.head()
# Out:
#     Case Number       Date  Year        Type                     Country  \
# 0    2021.09.10  10-Sep-21  2021         NaN                       EGYPT
# 1    2021.09.09   9-Sep-21  2021  Unprovoked                         USA
# 2    2021.09.05   5-Sep-21  2021  Unprovoked                   AUSTRALIA
# 3  2021.09.03.b   3-Sep-21  2021  Unprovoked  British Overseas Territory
# 4    2021.08.28  28-Aug-21  2021  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#                Name Gender  ...               Species   \
# 0           Mohamed      M  ...  No shark invovlement
# 1     Doyle Neilsen      M  ...                    NaN
# 2  Timothy Thompson      M  ...            White xhark
# 3              male      M  ...                    NaN
# 4              male      M  ...                    NaN
#
#                              Investigator or Source  \
# 0                           Dr. M. Fouda & M. Salrm
# 1             Daytona Beach News-Journal, 9/14/2021
# 2                                    B. Myatt, GSAF
# 3                                         Anonymous
# 4  T. Craig, GSAF  & K. McMurray, TrackingShark.com
#
#                             pdf  \
# 0        2021.09.10-Mohamed.pdf
# 1        2021.09.09-Neilsen.pdf
# 2       2021.09.05-Thompson.pdf
# 3  2021.09.03.b-TurksCaicos.pdf
# 4     2021.08.28.-Galveston.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.10
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.09
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.09.05
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2021.09.03.b
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.08.28
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2021.09.10         6700.0         NaN         NaN
# 1    2021.09.09         6699.0         NaN         NaN
# 2    2021.09.05         6698.0         NaN         NaN
# 3  2021.09.03.b         6697.0         NaN         NaN
# 4    2021.08.28         6696.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
# List all column names
print(shark_attack_df.columns.values.tolist())
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Gender', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
# Remove all of the extra "unnamed" columns at the end of the dataset
for column in shark_attack_df.columns:
    if 'Unnamed:' in column:
        shark_attack_df.drop(columns=column, inplace=True)

# Drop other unnecessary columns
shark_attack_df.drop(columns=['Date', 'Name', 'Investigator or Source', 'href', 'pdf', 'Injury',
                              'original order', 'Species ', 'Case Number.1', 'Case Number.2'], inplace=True)

shark_attack_df.head()
# Out:
#     Case Number  Year        Type                     Country  \
# 0    2021.09.10  2021         NaN                       EGYPT
# 1    2021.09.09  2021  Unprovoked                         USA
# 2    2021.09.05  2021  Unprovoked                   AUSTRALIA
# 3  2021.09.03.b  2021  Unprovoked  British Overseas Territory
# 4    2021.08.28  2021  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#   Gender  Age Fatal (Y/N)   Time  \
# 0      M  NaN         NaN    NaN
# 1      M   !6           N  13h20
# 2      M   31           Y  10h30
# 3      M  NaN           N    NaN
# 4      M   !!           N  11h45
#
#                                         href formula
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Display number of rows and columns
shark_attack_df.shape
# Out:
# (25840, 12)

# %% [markdown]
# ### Clean Year column

# %%
# Update year column to number
shark_attack_df["Year"]=pd.to_numeric(shark_attack_df["Year"],errors='coerce')
# Remove any rows with data older than 1950 or are empty
shark_attack_df = shark_attack_df[shark_attack_df['Year'] >= 1950]

shark_attack_df.shape
# Out:
# (4887, 12)

# %% [markdown]
# ### Clean type Column

# %%
# Determine values in 'Type' column
shark_attack_df['Type'].value_counts()
# Out:
# Unprovoked             3655
# Provoked                469
# Invalid                 381
# Watercraft              251
# Sea Disaster             98
# Questionable             12
# Boat                      7
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Name: Type, dtype: int64

# %%
# Remove types that are 'Invalid' as they are not shark related injuries or deaths
# Also remove types that have not been deteremined as shark attack
values_list = ['Invalid','Questionable','Unconfirmed','Unverified','Under investigation']
shark_attack_df = shark_attack_df[~shark_attack_df['Type'].isin(values_list)]
# Combine "Boat" and "Watercraft" types
shark_attack_df['Type'] = shark_attack_df['Type'].str.replace('Boat','Watercraft')
shark_attack_df.shape
# Out:
# (4491, 12)

# %%
# Check value counts for 'Type'
shark_attack_df['Type'].value_counts()
# Out:
# Unprovoked      3655
# Provoked         469
# Watercraft       258
# Sea Disaster      98
# Name: Type, dtype: int64

# %% [markdown]
# ### Clean Date Column

# %%
# Rename Case Number column to Date
shark_attack_df.rename(columns = {'Case Number':'Date'}, inplace = True)
# If the date will be missing the day value, update it to 1st of the month
shark_attack_df['Date'] = shark_attack_df['Date'].str.replace('.00.[a-zA-z]','01',regex="True")
shark_attack_df['Date'] = shark_attack_df['Date'].str.replace('.00 ','01',regex="True")
# Select first 10 characters and convert to date
shark_attack_df['Date'] = shark_attack_df['Date'].str[:10]
shark_attack_df['Date'] = pd.to_datetime(shark_attack_df['Date'], errors='coerce')
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#   Gender  Age Fatal (Y/N)   Time  \
# 0      M  NaN         NaN    NaN
# 1      M   !6           N  13h20
# 2      M   31           Y  10h30
# 3      M  NaN           N    NaN
# 4      M   !!           N  11h45
#
#                                         href formula
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
shark_attack_df.shape
# Out:
# (4491, 12)

# %%
# Determine how many rows without a valid date
shark_attack_df[shark_attack_df.Date.isnull()]
# Out:
#      Date    Year        Type           Country               Area  \
# 10    NaT  2021.0  Unprovoked               USA            Florida
# 83    NaT  2021.0  Unprovoked            BRAZIL         Pernambuco
# 378   NaT  2018.0  Unprovoked             EGYPT                NaN
# 386   NaT  2018.0    Provoked         AUSTRALIA  Westerm Australia
# 659   NaT  2016.0  Unprovoked               USA          Louisiana
# ...   ...     ...         ...               ...                ...
# 4840  NaT  1951.0  Unprovoked          COLUMBIA      Caribbean Sea
# 4844  NaT  1951.0  Unprovoked  FRENCH POLYNESIA           Tuamotus
# 4855  NaT  1951.0  Unprovoked        NEW GUINEA    Madang Province
# 4865  NaT  1950.0  Unprovoked      SAUDI ARABIA   Eastern Province
# 4872  NaT  1950.0  Unprovoked               USA            Florida
#
#                                                Location  \
# 10                             Key Largo, Monroe County
# 83                               Cacimba do Padre Beach
# 378                                     Brothers Island
# 386                                          Dugong Bay
# 659                                                 NaN
# ...                                                 ...
# 4840                                          Cartegena
# 4844  Outer edge of Hikueru, one of the Central Tuam...
# 4855                                       Manam Island
# 4865                East of the Ras Tanura-Jubail area
# 4872              Rock Harbor, Key Largo, Monroe County
#
#                                                Activity Gender  Age  \
# 10                                           Snorkeling      M   15
# 83                                              Surfing      M   52
# 378                                        Scuba Diving      M  NaN
# 386                                      Feeding sharks      F   34
# 659                                              Wading      F   33
# ...                                                 ...    ...  ...
# 4840                                            Bathing    NaN  NaN
# 4844                                       Spearfishing      M   39
# 4855                                                NaN    NaN  NaN
# 4865                                             Diving      M  NaN
# 4872  Goggle-diving for seaweeds, but standing in water      M   21
#
#      Fatal (Y/N)                 Time  \
# 10             N                07h51
# 83             N                  NaN
# 378            N                  NaN
# 386            N                  NaN
# 659            N                  NaN
# ...          ...                  ...
# 4840           Y                  NaN
# 4844           N                11h00
# 4855           Y                  NaN
# 4865           N  2 hrs before sunset
# 4872           N                  NaN
#
#                                            href formula
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 83    http://sharkattackfile.net/spreadsheets/pdf_di...
# 378   http://sharkattackfile.net/spreadsheets/pdf_di...
# 386   http://sharkattackfile.net/spreadsheets/pdf_di...
# 659   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 4840  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4844  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4855  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4865  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4872  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [154 rows x 12 columns]

# %% [markdown]
# ### Clean up Fatal column

# %%
# Clean up Fatal Column
# Rename 'Fatal (Y/N)' column to be just 'Fatal'  
shark_attack_df.rename(columns = {'Fatal (Y/N)':'Fatal'}, inplace = True)

# %%
# Check value counts for 'Fatal'
shark_attack_df['Fatal'].value_counts()
# Out:
# N          3755
# Y           660
# UNKNOWN      43
#  N            7
# Y x 2         1
# 2017          1
# Nq            1
# M             1
# Name: Fatal, dtype: int64

# %%
shark_attack_df['Fatal'] = shark_attack_df['Fatal'].str.replace(' N','N')
shark_attack_df['Fatal'] = shark_attack_df['Fatal'].str.replace('Nq','N')
shark_attack_df['Fatal'] = shark_attack_df['Fatal'].str.replace('Y x 2','Y')
shark_attack_df['Fatal'] = shark_attack_df['Fatal'].str.replace('2017','UNKNOWN')
shark_attack_df['Fatal'] = shark_attack_df['Fatal'].str.replace('M','UNKNOWN')
shark_attack_df['Fatal'].value_counts()
# Out:
# N          3763
# Y           661
# UNKNOWN      45
# Name: Fatal, dtype: int64

# %% [markdown]
# ### Clean up Gender column

# %%
# Check value counts for 'Gender'
shark_attack_df['Gender'].value_counts()
# Out:
# M        3564
# F         561
# M           2
# lli         1
# M x 2       1
# Name: Gender, dtype: int64

# %%
shark_attack_df['Gender'] = shark_attack_df['Gender'].str.replace('^M.*','M',regex="True")
shark_attack_df['Gender'] = shark_attack_df['Gender'].str.replace('lli','UNKNOWN')
shark_attack_df['Gender'].value_counts()
# Out:
# M          3567
# F           561
# UNKNOWN       1
# Name: Gender, dtype: int64

# %%
shark_attack_df.shape
# Out:
# (4491, 12)

# %% [markdown]
# ### Clean Age column

# %%
# Update age column to number
shark_attack_df['Age']=pd.to_numeric(shark_attack_df['Age'],errors='coerce')
shark_attack_df['Age'] = shark_attack_df['Age'].replace(np.nan, 0, regex=True)
shark_attack_df['Age'] = shark_attack_df['Age'].astype(int)
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#   Gender  Age Fatal   Time                                       href formula
# 0      M    0   NaN    NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      M    0     N  13h20  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      M   31     Y  10h30  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      M    0     N    NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      M    0     N  11h45  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
shark_attack_df.shape
# Out:
# (4491, 12)

# %% [markdown]
# ### Clean Time column

# %%
# Replace 'h' denoting hours with ":"
shark_attack_df['Time'] = shark_attack_df['Time'].str.replace('h',':',regex="True")
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#   Gender  Age Fatal   Time                                       href formula
# 0      M    0   NaN    NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      M    0     N  13:20  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      M   31     Y  10:30  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      M    0     N    NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      M    0     N  11:45  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
shark_attack_df['Time'].value_counts()
# Out:
# Afternoon                         152
# 11:00                             115
# Morning                           107
# 14:00                             102
# 15:00                              99
#                                  ...
# 10:07                               1
# 07:56                               1
# 11:51                               1
# Sometime between 06:00 & 08:oo      1
# 13:23                               1
# Name: Time, Length: 357, dtype: int64

# %%
shark_attack_df['Time'] = pd.to_datetime(shark_attack_df['Time'], format='%H:%M', errors='coerce').dt.time

# %%
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location         Activity  \
# 0               NaN                  Sidi Abdel Rahmen          Swimming
# 1           Florida         Ponce Inlet, Volusia County          Surfing
# 2   New South Wales                       Emerald Beach          Surfing
# 3  Turks and Caicos                                 NaN              NaN
# 4             Texas  Galveston Island, Galveston County  Boogie boarding
#
#   Gender  Age Fatal      Time  \
# 0      M    0   NaN       NaT
# 1      M    0     N  13:20:00
# 2      M   31     Y  10:30:00
# 3      M    0     N       NaT
# 4      M    0     N  11:45:00
#
#                                         href formula
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Determine how many rows without a valid time
shark_attack_df[shark_attack_df.Time.isnull()]
# Out:
#            Date    Year        Type                     Country  \
# 0    2021-09-10  2021.0         NaN                       EGYPT
# 3    2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 7    2021-08-13  2021.0  Unprovoked                      CANADA
# 8    2021-08-07  2021.0    Provoked                   AUSTRALIA
# 15   2021-07-27  2021.0  Unprovoked                         USA
# ...         ...     ...         ...                         ...
# 4894 1950-01-01  1950.0  Unprovoked                      GREECE
# 4895 1950-01-01  1950.0  Unprovoked                   SINGAPORE
# 4896 1950-01-01  1950.0  Unprovoked               NEW CALEDONIA
# 4897 1950-01-01  1950.0  Unprovoked               NEW CALEDONIA
# 4898 1950-01-01  1950.0  Unprovoked                        FIJI
#
#                   Area                      Location  \
# 0                  NaN            Sidi Abdel Rahmen
# 3     Turks and Caicos                           NaN
# 7          Nova Scotia            Cape Breton Island
# 8           Queensland     North Stradbroke Island
# 15             Georgia  Tybee Island, Chatham County
# ...                ...                           ...
# 4894               NaN               Piraeus, Athens
# 4895  Singapore Harbor                           NaN
# 4896    North Province           Voh, near meatworks
# 4897    North Province    Mangalia Reef above Touho
# 4898               NaN                  Near Lautoka
#
#                                                Activity Gender  Age Fatal  \
# 0                                              Swimming      M    0   NaN
# 3                                                   NaN      M    0     N
# 7                                              Swimming      F   21     N
# 8                                      Harassing sharks      M    0     N
# 15                                              Surfing      M   58     N
# ...                                                 ...    ...  ...   ...
# 4894                                           Swimming    NaN    0     Y
# 4895                                   Diving for coins      M    0     Y
# 4896  Spearfishing, but walking carrying fish on end...      M    0     N
# 4897            Helmet diving, collecting trochus shell      M    0     N
# 4898                                                NaN      M    0     N
#
#      Time                                       href formula
# 0     NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7     NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 15    NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...   ...                                                ...
# 4894  NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4895  NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4896  NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4897  NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4898  NaT  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [2257 rows x 12 columns]

# %%
shark_attack_df.shape
# Out:
# (4491, 12)

# %% [markdown]
# ### Clean Activity column

# %%
# Pull out key words for common activities to 'bucket' the activities
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Bb]oating.*','Boating',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Dd]iving.*','Diving',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ff]ishing.*','Fishing',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ss]urfing.*','Surfing and Other Board Sports',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Bb]oarding.*','Surfing and Other Board Sports',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ss]wimming.*','Swimming',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ss]inking.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Cc]apsize.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ee]xplode.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ss]ank.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Cc]rash.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Dd]isaster.*','Sea Disaster',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ss]norkel.*','Snorkeling',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Ww]ading.*','Wading',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Kk]ayak.*','Kayaking or Canoeing',regex="True")
shark_attack_df['Activity'] = shark_attack_df['Activity'].str.replace('.*[Cc]anoe.*','Kayaking or Canoeing',regex="True")

shark_attack_df['Activity'] = np.where((shark_attack_df['Activity'] != 'Boating') &
                                      (shark_attack_df['Activity'] != 'Diving') &
                                      (shark_attack_df['Activity'] != 'Fishing') &
                                      (shark_attack_df['Activity'] != 'Surfing and Other Board Sports') &
                                      (shark_attack_df['Activity'] != 'Swimming') &
                                      (shark_attack_df['Activity'] != 'Sea Disaster') &
                                      (shark_attack_df['Activity'] != 'Snorkeling') &
                                      (shark_attack_df['Activity'] != 'Wading') &
                                      (shark_attack_df['Activity'] != 'Kayaking or Canoeing'), 'Other', shark_attack_df['Activity']
                                      )

# %%
#pd.set_option("display.max_rows", None)
shark_attack_df['Activity'].value_counts()
# Out:
# Surfing and Other Board Sports    1332
# Fishing                            881
# Other                              875
# Swimming                           648
# Diving                             379
# Wading                             146
# Snorkeling                         115
# Sea Disaster                        62
# Kayaking or Canoeing                51
# Boating                              2
# Name: Activity, dtype: int64

# %%
shark_attack_df.shape
# Out:
# (4491, 12)

# %% [markdown]
# ### Merge ISO Codes into shark attack file

# %%
# Merge ISO codes into shark_attack_df
shark_attack_df = shark_attack_df.merge(ISO_df, how='left', left_on='Country', right_on='Official state name')
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location  \
# 0               NaN                  Sidi Abdel Rahmen
# 1           Florida         Ponce Inlet, Volusia County
# 2   New South Wales                       Emerald Beach
# 3  Turks and Caicos                                 NaN
# 4             Texas  Galveston Island, Galveston County
#
#                          Activity Gender  Age Fatal      Time  \
# 0                        Swimming      M    0   NaN       NaT
# 1  Surfing and Other Board Sports      M    0     N  13:20:00
# 2  Surfing and Other Board Sports      M   31     Y  10:30:00
# 3                           Other      M    0     N       NaT
# 4  Surfing and Other Board Sports      M    0     N  11:45:00
#
#                                         href formula Official state name  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...               EGYPT
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...                 USA
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...           AUSTRALIA
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...                 USA
#
#   ISO_code
# 0       EG
# 1       US
# 2       AU
# 3      NaN
# 4       US

# %%
# Determine how many rows without an ISO code
#pd.set_option("display.max_rows", None)
ISO_null_values = shark_attack_df[shark_attack_df.ISO_code.isnull()]

# %%
ISO_null_values
# Out:
#            Date    Year          Type                                Country  \
# 3    2021-09-03  2021.0    Unprovoked             British Overseas Territory
# 86   2021-01-09  2021.0    Unprovoked                       ST KITTS / NEVIS
# 93   2020-12-10  2020.0    Unprovoked                              ST MARTIN
# 409  2017-11-13  2017.0    Unprovoked                                    NaN
# 454  2017-07-24  2017.0    Unprovoked  ST HELENA, British overseas territory
# ...         ...     ...           ...                                    ...
# 4348        NaT  1954.0      Provoked                                 SUDAN?
# 4375 1953-07-11  1953.0  Sea Disaster                          PACIFIC OCEAN
# 4386 1953-01-01  1953.0  Sea Disaster                           INDIAN OCEAN
# 4415 1952-03-30  1952.0    Unprovoked                   NETHERLANDS ANTILLES
# 4439 1951-07-11  1951.0    Unprovoked                          PACIFIC OCEAN
#
#                                       Area  \
# 3                         Turks and Caicos
# 86                             The Narrows
# 93                                     NaN
# 409                                    NaN
# 454                       Ascension Island
# ...                                    ...
# 4348                               Red Sea
# 4375  330 to 350 miles east of Wake Island
# 4386                                   NaN
# 4415                               Curacao
# 4439                                   NaN
#
#                                       Location  \
# 3                                          NaN
# 86                                Booby Island
# 93                                Orient Beach
# 409                                        NaN
# 454                                English Bay
# ...                                        ...
# 4348                            Southern part
# 4375                                       NaN
# 4386  Between Straits of Malacca and Sri Lanka
# 4415                                       NaN
# 4439      In Los Angeles – Honolulu yacht race
#
#                             Activity Gender  Age Fatal      Time  \
# 3                              Other      M    0     N       NaT
# 86                          Swimming      F   26     N       NaT
# 93                          Swimming      F   39     Y  14:00:00
# 409   Surfing and Other Board Sports      M   24     N       NaT
# 454   Surfing and Other Board Sports      M   37     N  17:00:00
# ...                              ...    ...  ...   ...       ...
# 4348                         Fishing      M    0     N       NaT
# 4375                           Other    NaN    0     N       NaT
# 4386                           Other    NaN    0     Y       NaT
# 4415                           Other      M    0     N       NaT
# 4439                           Other      M   40     N       NaT
#
#                                            href formula Official state name  \
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 86    http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 93    http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 409   http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 454   http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# ...                                                 ...                 ...
# 4348  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 4375  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 4386  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 4415  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
# 4439  http://sharkattackfile.net/spreadsheets/pdf_di...                 NaN
#
#      ISO_code
# 3         NaN
# 86        NaN
# 93        NaN
# 409       NaN
# 454       NaN
# ...       ...
# 4348      NaN
# 4375      NaN
# 4386      NaN
# 4415      NaN
# 4439      NaN
#
# [137 rows x 14 columns]

# %%
ISO_null_values['Country'].value_counts()
# Out:
# HONG KONG                                23
# SOUTH KOREA                               8
# ATLANTIC OCEAN                            6
# NEW BRITAIN                               6
# PACIFIC OCEAN                             6
# TURKS & CAICOS                            5
# MID ATLANTIC OCEAN                        4
# CARIBBEAN SEA                             4
# SCOTLAND                                  4
# NORTH PACIFIC OCEAN                       4
# FRANCE                                    4
# OKINAWA                                   4
# AZORES                                    3
# ST HELENA, British overseas territory     2
# Fiji                                      2
#  TONGA                                    2
# NORTH ATLANTIC OCEAN                      2
# PERSIAN GULF                              2
# PACIFIC OCEAN                             2
# British Overseas Territory                1
# ADMIRALTY ISLANDS                         1
# NICARAGUA                                 1
# NAMIBIA                                   1
# RED SEA / INDIAN OCEAN                    1
# SUDAN?                                    1
# SOUTH ATLANTIC OCEAN                      1
# ST MARTIN                                 1
# UNITED ARAB EMIRATES (UAE)                1
# WESTERN SAMOA                             1
# NORTH SEA                                 1
# EGYPT / ISRAEL                            1
# GULF OF ADEN                              1
# ST KITTS / NEVIS                          1
# NORTHERN ARABIAN SEA                      1
# NETHERLANDS ANTILLES                      1
# GRAND CAYMAN                              1
# MEXICO                                    1
# ANDAMAN / NICOBAR ISLANDAS                1
# PALESTINIAN TERRITORIES                   1
# BRITISH WEST INDIES                       1
# Sierra Leone                              1
# THE BALKANS                               1
# SOUTH PACIFIC OCEAN                       1
# BRITISH ISLES                             1
# JOHNSTON ISLAND                           1
# NORTH ATLANTIC OCEAN                      1
# FEDERATED STATES OF MICRONESIA            1
# INDIAN OCEAN                              1
# DIEGO GARCIA                              1
# RED SEA                                   1
# SOUTH CHINA SEA                           1
# ST. MAARTIN                               1
# Name: Country, dtype: int64

# %%
# Drop extra country column
shark_attack_df.drop(columns=['Official state name'], inplace=True)
shark_attack_df.head()
# Out:
#         Date    Year        Type                     Country  \
# 0 2021-09-10  2021.0         NaN                       EGYPT
# 1 2021-09-09  2021.0  Unprovoked                         USA
# 2 2021-09-05  2021.0  Unprovoked                   AUSTRALIA
# 3 2021-09-03  2021.0  Unprovoked  British Overseas Territory
# 4 2021-08-28  2021.0  Unprovoked                         USA
#
#                Area                            Location  \
# 0               NaN                  Sidi Abdel Rahmen
# 1           Florida         Ponce Inlet, Volusia County
# 2   New South Wales                       Emerald Beach
# 3  Turks and Caicos                                 NaN
# 4             Texas  Galveston Island, Galveston County
#
#                          Activity Gender  Age Fatal      Time  \
# 0                        Swimming      M    0   NaN       NaT
# 1  Surfing and Other Board Sports      M    0     N  13:20:00
# 2  Surfing and Other Board Sports      M   31     Y  10:30:00
# 3                           Other      M    0     N       NaT
# 4  Surfing and Other Board Sports      M    0     N  11:45:00
#
#                                         href formula ISO_code
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...       EG
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...       US
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...       AU
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...      NaN
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...       US

# %%
shark_attack_df.shape
# Out:
# (4491, 13)

# %%
# Set up engine to transfer our shark attack df to PostgreSQL
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/shark_attack_data"
engine = create_engine(db_string)
    
# Upload shark_attack_df to a SQL database
shark_attack_df.to_sql(name='shark_attacks', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-42-92ad694ffdab> in <module>
#       4
#       5 # Upload shark_attack_df to a SQL database
# ----> 6 shark_attack_df.to_sql(name='shark_attacks', con=engine, if_exists='replace')
#       7
#       8
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2787             chunksize=chunksize,
#    2788             dtype=dtype,
# -> 2789             method=method,
#    2790         )
#    2791
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     608         chunksize=chunksize,
#     609         dtype=dtype,
# --> 610         method=method,
#     611     )
#     612
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404             dtype=dtype,
#    1405         )
# -> 1406         table.create()
#    1407
#    1408         from sqlalchemy import exc
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     734
#     735     def create(self):
# --> 736         if self.exists():
#     737             if self.if_exists == "fail":
#     738                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in exists(self)
#     718
#     719     def exists(self):
# --> 720         return self.pd_sql.has_table(self.name, self.schema)
#     721
#     722     def sql_schema(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1452             import sqlalchemy as sa
#    1453
# -> 1454             insp = sa.inspect(self.connectable)
#    1455             return insp.has_table(name, schema or self.meta.schema)
#    1456         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3143             if connection is None:
#    3144                 Connection._handle_dbapi_exception_noconnection(
# -> 3145                     e, dialect, self
#    3146                 )
#    3147             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002         elif should_wrap:
#    2003             util.raise_(
# -> 2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#    2006         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
