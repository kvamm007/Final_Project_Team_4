# %%
import pandas as pd

# %%
#Read in CSV
file_name="LatLngSample.csv"
shark_df=pd.read_csv(file_name)
shark_df.head()
# Out:
#         Date  Year        Type                     Country ISO Code  \
# 0   9-Sep-21  2021  Unprovoked                         USA       US
# 1   5-Sep-21  2021  Unprovoked                   AUSTRALIA       AU
# 2   3-Sep-21  2021  Unprovoked  British Overseas Territory       TC
# 3  28-Aug-21  2021  Unprovoked                         USA       US
# 4   3-Sep-21  2021  Unprovoked                         USA       US
#
#                Area                            Location  \
# 0           Florida         Ponce Inlet, Volusia County
# 1   New South Wales                       Emerald Beach
# 2  Turks and Caicos                                 NaN
# 3             Texas  Galveston Island, Galveston County
# 4         Louisiana                      off Grand Isle
#
#                  Activity              Name Sex   Age  \
# 0                 Surfing     Doyle Neilsen    M   !6
# 1                 Surfing  Timothy Thompson    M   31
# ...
